# %%
accession_list = [
    'GSM3359499', 
'GSM3359500', 
'GSM4030401', 
'GSM4030402', 
'GSM4030403', 
'GSM4030404', 
'GSM4030405', 
'GSM3406869', 
'GSM3406870', 
'SAMEA3892105', 
'SAMEA3892106', 
'SAMEA3892107', 
'SAMEA3892109', 
'SAMEA3892110', 
'SAMEA3892081', 
'SAMEA3892082', 
'SAMEA3892083', 
'SAMEA3892084', 
'SAMEA3892085', 
'GSM831503', 
'GSM831504', 
'GSM3165252', 
'GSM3165251', 
'GSM3406871', 
'GSM3406872', 
'SAMEA3892087', 
'SAMEA3892088', 
'SAMEA3892089', 
'SAMEA3892090', 
'SAMEA3892091', 
'GSM1289382', 
'GSM3165256', 
'GSM3165257', 
'GSM831505', 
'GSM831506', 
'GSM3406873', 
'GSM3406874', 
'SAMEA3892099', 
'SAMEA3892100', 
'SAMEA3892101', 
'SAMEA3892102', 
'SAMEA3892104', 
'GSM4030419', 
'GSM4030420', 
'GSM4030421', 
'GSM4030422', 
'GSM4030423', 
'GSM1531258', 
'GSM3467111', 
'GSM3467112', 
'GSM3467119', 
'GSM3467120', 
'GSM3406875', 
'GSM3406876', 
'GSM831507', 
'GSM831508', 
'GSM3165225', 
'GSM3165224', 
'SAMEA3892075', 
'SAMEA3892076', 
'SAMEA3892077', 
'SAMEA3892078', 
'SAMEA3892079', 
'SAMEA3892004', 
'SAMEA3892005', 
'SAMEA3892006', 
'SAMEA3892007', 
'SAMEA3892008', 
'GSM831509', 
'GSM831510', 
'GSM831511', 
'GSM3406877', 
'GSM3406878', 
'SAMEA3892050', 
'SAMEA3892051', 
'SAMEA3892052', 
'SAMEA3892054', 
'SAMEA3892055', 
'GSM3689553', 
'GSM3689554', 
'GSM3467113', 
'GSM3467114', 
'GSM3689557', 
'GSM3689558', 
'GSM3467121', 
'GSM3467122', 
'SAMEA3892056', 
'SAMEA3892057', 
'SAMEA3892058', 
'SAMEA3892060', 
'SAMEA3892061', 
'GSM831512', 
'GSM831513', 
'SAMEA3892093', 
'SAMEA3892094', 
'SAMEA3892095', 
'SAMEA3892096', 
'SAMEA3892097', 
'SAMEA3892063', 
'SAMEA3892064', 
'SAMEA3892065', 
'SAMEA3892066', 
'SAMEA3892067', 
'GSM3855892', 
'GSM3855893', 
'SAMEA3892069', 
'SAMEA3892070', 
'SAMEA3892071', 
'SAMEA3892072', 
'SAMEA3892073', 
'GSM3689555', 
'GSM3689556', 
'GSM3467115', 
'GSM3467116', 
'GSM3357427', 
'GSM3357428', 
'GSM3357429', 
'GSM3357430', 
'GSM3357431', 
'GSM3357432', 
'SAMEA3892009', 
'SAMEA3892010', 
'SAMEA3892011', 
'SAMEA3892012', 
'SAMEA3892013', 
'GSM3689559', 
'GSM3689560', 
'GSM3467123', 
'GSM3467124', 
'GSM831514', 
'GSM831515', 
'GSM4232662', 
'GSM4232663', 
'GSM4232664', 
'SAMEA3892014', 
'SAMEA3892015', 
'SAMEA3892016', 
'SAMEA3892017', 
'SAMEA3892018', 
'GSM3403638', 
'GSM3403639', 
'GSM3403640', 
'GSM3403641', 
'GSM3996849', 
'GSM3996850', 
'GSM3996851', 
'GSM3403642', 
'GSM3403643', 
'GSM3494527', 
'GSM3494528', 
'GSM3494529', 
'GSM4232671', 
'GSM4232672', 
'GSM4232673', 
'SAMEA3892019', 
'SAMEA3892020', 
'SAMEA3892021', 
'SAMEA3892023', 
'SAMEA3892024', 
'GSM3467117', 
'GSM3467118', 
'GSM3467125', 
'GSM3467126', 
'GSM831516', 
'GSM831517', 
'SAMEA3892025', 
'SAMEA3892026', 
'SAMEA3892028', 
'SAMEA3892029', 
'SAMEA3892030', 
'GSM3855896', 
'GSM3855897', 
'GSM3855899', 
'GSM3855900', 
'GSM3403644', 
'GSM3403645', 
'GSM3855901', 
'GSM3855902', 
'GSM3678229', 
'GSM3678230', 
'GSM3403646', 
'GSM3403647', 
'GSM3403648', 
'GSM3403649', 
'GSM3403650', 
'GSM3403651', 
'SAMEA3892031', 
'SAMEA3892032', 
'SAMEA3892034', 
'SAMEA3892035', 
'SAMEA3892036', 
'GSM3855905', 
'GSM3855906', 
'GSM3855909', 
'GSM3855910', 
'GSM3996852', 
'GSM3996853', 
'GSM3996854', 
'GSM3855911', 
'GSM3855912', 
'GSM3403652', 
'GSM3403653', 
'GSM3403654', 
'GSM3403655', 
'GSM3403656', 
'GSM3403657', 
'GSM3381530', 
'GSM3381531', 
'GSM3381532', 
'GSM3381524', 
'GSM3381525', 
'GSM3381526', 
'GSM3381533', 
'GSM3381534', 
'GSM3381527', 
'GSM3381528', 
'GSM3381529', 
'SAMEA3892037', 
'SAMEA3892038', 
'SAMEA3892040', 
'SAMEA3892041', 
'SAMEA3892042', 
'GSM831518', 
'GSM831519', 
'GSM4237576', 
'GSM4237577', 
'GSM4237578', 
'SAMEA3892044', 
'SAMEA3892045', 
'SAMEA3892046', 
'SAMEA3892047', 
'SAMEA3892049', 
'GSM3381535', 
'GSM3381536', 
'GSM3381537', 
'GSM3381538', 
'GSM3381539', 
'GSM3381540', 
'GSM3395204', 
'GSM3693045', 
'GSM3693046', 
'GSM3693047', 
'GSM3403658', 
'GSM3403659', 
'GSM3403660', 
'GSM3403661', 
'GSM3612308', 
'GSM3612309', 
'GSM3612310', 
'GSM3612311', 
'GSM3612312', 
'GSM3612313', 
'GSM3612314', 
'GSM3612315', 
'GSM3612316', 
'GSM3612317', 
'GSM3612318', 
'GSM3612319', 
'GSM3612320', 
'GSM3612321', 
'GSM3612322', 
'GSM3612323', 
'GSM3612324', 
'GSM3896450', 
'GSM3896451', 
'GSM3896449', 
'GSM3324249', 
'GSM3324250', 
'GSM3324251', 
'GSM3324252', 
'GSM2432109', 
'GSM2432110', 
'GSM2432111', 
'GSM2432106', 
'GSM2432107', 
'GSM2432108', 
'GSM3754093', 
'GSM3754094', 
'GSM3754095', 
'GSM3847460', 
'GSM3847461', 
'GSM3847462', 
'GSM4057878', 
'GSM4057879', 
'GSM4057880', 
'GSM3900726', 
'GSM3900727', 
'GSM3900728', 
'GSM3900729', 
'GSM3900730', 
'GSM1081558', 
'GSM1081559', 
'GSM1081560', 
]

# %%
print(', '.join(accession_list))
# Out:
# GSM3359499, GSM3359500, GSM4030401, GSM4030402, GSM4030403, GSM4030404, GSM4030405, GSM3406869, GSM3406870, SAMEA3892105, SAMEA3892106, SAMEA3892107, SAMEA3892109, SAMEA3892110, SAMEA3892081, SAMEA3892082, SAMEA3892083, SAMEA3892084, SAMEA3892085, GSM831503, GSM831504, GSM3165252, GSM3165251, GSM3406871, GSM3406872, SAMEA3892087, SAMEA3892088, SAMEA3892089, SAMEA3892090, SAMEA3892091, GSM1289382, GSM3165256, GSM3165257, GSM831505, GSM831506, GSM3406873, GSM3406874, SAMEA3892099, SAMEA3892100, SAMEA3892101, SAMEA3892102, SAMEA3892104, GSM4030419, GSM4030420, GSM4030421, GSM4030422, GSM4030423, GSM1531258, GSM3467111, GSM3467112, GSM3467119, GSM3467120, GSM3406875, GSM3406876, GSM831507, GSM831508, GSM3165225, GSM3165224, SAMEA3892075, SAMEA3892076, SAMEA3892077, SAMEA3892078, SAMEA3892079, SAMEA3892004, SAMEA3892005, SAMEA3892006, SAMEA3892007, SAMEA3892008, GSM831509, GSM831510, GSM831511, GSM3406877, GSM3406878, SAMEA3892050, SAMEA3892051, SAMEA3892052, SAMEA3892054, SAMEA3892055, G
# ...
